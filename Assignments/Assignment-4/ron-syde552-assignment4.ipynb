# %% [markdown]
# # SYDE 552 Assignment 4: Basal Ganglia
# ### Due Monday, April 8, 11:59pm
# ### Value: 15% of total marks for the course
#
# This assignment covers various forms of Action Selection, covering a standard feed-forward neural network model and a winner-take-all model.  The last section adds biological details to the winner-take-all model (synapses).  The intent is to show the creation a modification of small specific-purpose networks and to explore how timing affects neurons.
#
# You can work in groups to do the assignment, but your answers and code must be original to you. Your submission will be a filled-out copy of this notebook (cells for code and written answers provided).

# %% [markdown]
# # 1. Action Selection with Feed-forward Neural Networks
#
# In order for the brain to choose which of many possible actions to select to perform at any given moment, it needs to be able to takke a list of numbers (indicating how good each action is in the current state, sometimes called the Value) and create an output that indicates which one is the largest.  For example, with the input `[0.2, 0.5, 0.8, 0.3]` we might want the output `[0, 0, 1, 0]`.
#
# One way to approach this task is to train a normal feed-forward neural network on this task.  This would be similar to the digit recognition task from Assignment 2, except we would just have the list of values as input instead of the image.
#
# To create the dataset for training the network, we can just generate a random set of values between 0 and 1, and then compute which one is biggest to produce our target value.

# %%
import numpy as np

N = 4        # how many values in the list
M = 10000    # how many random examples to make in the dataset

X = np.random.uniform(0,1,(M,N))
Y = np.argmax(X, axis=1)

# %% [markdown]
# In order to train with this data in pytorch, we need to turn that array into a pytorch dataset, and to split it into training and testing.

# %%
import torch
dataset = torch.utils.data.TensorDataset(torch.Tensor(X),torch.Tensor(Y).long()) # create your datset

train_dataset, test_dataset = torch.utils.data.random_split(dataset,[0.8,0.2])
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=1000, shuffle=True)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=1000, shuffle=True)

# %% [markdown]
# Now we have to define our network.  Here we define a simple neural network with 4 inputs, a hidden layer of 100 neurons, and 4 outputs.

# %%
import torch.nn as nn
import torch.nn.functional as F

class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.fc1 = nn.Linear(4, 100)    # the weights from the input to the new learned features (hidden layer)
        self.fc2 = nn.Linear(100, 4)    # the weights from the hidden layer to the output

    def forward(self, x):
        # the processing the network will do
        x = F.relu(self.fc1(x))         # apply the first set of weights, then apply the ReLU neuron model
        x = self.fc2(x)                 # apply the second set of weights
        return x
    
network = Net()

# %% [markdown]
# Finally, we have to train the model.  Here is the exact same code from Assignemnt 2 for training

# %%
# create the learning rule
optimizer = torch.optim.SGD(network.parameters(), 
                            lr=0.1,   # learning rate
                            momentum=0.5)

# variables to keep track of the training and testing accuracy
accuracy_train = []
accuracy_test = []

def continue_training():
    network.train()      # configure the network for training
    for i in range(10):  # train the network 10 times
        correct = 0
        for data, target in train_loader:       # working in batchs of 1000
            optimizer.zero_grad()               # initialize the learning system
            output = network(data)              # feed in the data 
            loss = F.nll_loss(output, target)   # compute how wrong the output is
            loss.backward()                     # change the weights to reduce error
            optimizer.step()                    # update the learning rule
            
            pred = output.data.max(1, keepdim=True)[1]           # compute which output is largest
            correct += pred.eq(target.data.view_as(pred)).sum()  # compute the number of correct outputs
    # update the list of training accuracy values
    score = float(correct/len(train_loader.dataset))
    accuracy_train.append(score)
    print('Iteration', len(accuracy_train), 'Training accuracy:', score)
    
    correct = 0
    network.eval()
    for data, target in test_loader:    # go through the test data once (in groups of 1000)
        output = network(data)                               # feed in the data
        pred = output.data.max(1, keepdim=True)[1]           # compute which output is largest
        correct += pred.eq(target.data.view_as(pred)).sum()  # compute the number of correct outputs
    # update the list of testing accuracy values
    score = float(correct/len(test_loader.dataset))
    accuracy_test.append(score)
    print('Iteration', len(accuracy_test), 'Testing accuracy:', score)

# %% [markdown]
# **1. a) [1 mark]** Call `continue_training()` 10 times and then plot the training and testing accuracy (as you did in assignment 2 question 3a.

# %%
import matplotlib.pyplot as plt
# call 10 times
for i in range(10):
    continue_training()

# plot
plt.figure(figsize=(12,4))
plt.plot(accuracy_train, label='training')
plt.plot(accuracy_test, label='testing')
plt.legend()
plt.xlabel('training iterations')
plt.ylabel('accuracy')
plt.show()
# Out:
# Iteration 1 Training accuracy: 0.25600001215934753
# Iteration 1 Testing accuracy: 0.2395000010728836
# Iteration 2 Training accuracy: 0.24449999630451202
# Iteration 2 Testing accuracy: 0.2395000010728836
# Iteration 3 Training accuracy: 0.24912500381469727
# Iteration 3 Testing accuracy: 0.2395000010728836
# Iteration 4 Training accuracy: 0.25600001215934753
# Iteration 4 Testing accuracy: 0.2395000010728836
# Iteration 5 Training accuracy: 0.24287499487400055
# Iteration 5 Testing accuracy: 0.25949999690055847
# Iteration 6 Training accuracy: 0.24287499487400055
# Iteration 6 Testing accuracy: 0.25949999690055847
# Iteration 7 Training accuracy: 0.24287499487400055
# Iteration 7 Testing accuracy: 0.25949999690055847
# Iteration 8 Training accuracy: 0.24287499487400055
# Iteration 8 Testing accuracy: 0.25949999690055847
# Iteration 9 Training accuracy: 0.24287499487400055
# Iteration 9 Testing accuracy: 0.25949999690055847
# Iteration 10 Training accuracy: 0.24287499487400055
# Iteration 10 Testing accuracy: 0.25949999690055847

# %% [markdown]
# **1. b) [1 mark]** In the previous question, the model did not get a very high accuracy.  To try to improve the accuracy, let's vary the number of neurons.  Try using 200 neurons, 500 neurons, and 1000 neurons.  For each one, generate the same plot as in 1a.  Does making the network larger in this way improve performance significantly?

# %%
# define class Net with x neurons
class Net(nn.Module):
    def __init__(self, x):
        super(Net, self).__init__()
        self.fc1 = nn.Linear(4, x)    # the weights from the input to the new learned features (hidden layer)
        self.fc2 = nn.Linear(x, 4)    # the weights from the hidden layer to the output

    def forward(self, x):
        # the processing the network will do
        x = F.relu(self.fc1(x))         # apply the first set of weights, then apply the ReLU neuron model
        x = self.fc2(x)                 # apply the second set of weights
        return x

# %%
network = Net(200)

# create the learning rule
optimizer = torch.optim.SGD(network.parameters(), 
                            lr=0.1,   # learning rate
                            momentum=0.5)

# variables to keep track of the training and testing accuracy
accuracy_train = []
accuracy_test = []

for i in range(10):
    continue_training()

# plot
plt.figure(figsize=(12,4))
plt.plot(accuracy_train, label='training')
plt.plot(accuracy_test, label='testing')
plt.legend()
plt.xlabel('training iterations')
plt.ylabel('accuracy')
plt.show()
# Out:
# Iteration 1 Training accuracy: 0.25600001215934753
# Iteration 1 Testing accuracy: 0.2395000010728836
# Iteration 2 Training accuracy: 0.25600001215934753
# Iteration 2 Testing accuracy: 0.2395000010728836
# Iteration 3 Training accuracy: 0.25600001215934753
# Iteration 3 Testing accuracy: 0.2395000010728836
# Iteration 4 Training accuracy: 0.2487500011920929
# Iteration 4 Testing accuracy: 0.2395000010728836
# Iteration 5 Training accuracy: 0.24287499487400055
# Iteration 5 Testing accuracy: 0.25949999690055847
# Iteration 6 Training accuracy: 0.24287499487400055
# Iteration 6 Testing accuracy: 0.25949999690055847
# Iteration 7 Training accuracy: 0.24287499487400055
# Iteration 7 Testing accuracy: 0.25949999690055847
# Iteration 8 Training accuracy: 0.24287499487400055
# Iteration 8 Testing accuracy: 0.25949999690055847
# Iteration 9 Training accuracy: 0.24287499487400055
# Iteration 9 Testing accuracy: 0.25949999690055847
# Iteration 10 Training accuracy: 0.24287499487400055
# Iteration 10 Testing accuracy: 0.25949999690055847

# %% [markdown]
# **Answer:**
#
# The accuracy of the model does not improve significantly by increasing the number of neurons. The accuracy of the model is around 0.25 for all the cases.

# %%
network = Net(500)

# create the learning rule
optimizer = torch.optim.SGD(network.parameters(), 
                            lr=0.1,   # learning rate
                            momentum=0.5)

# variables to keep track of the training and testing accuracy
accuracy_train = []
accuracy_test = []

for i in range(10):
    continue_training()

# plot
plt.figure(figsize=(12,4))
plt.plot(accuracy_train, label='training')
plt.plot(accuracy_test, label='testing')
plt.legend()
plt.xlabel('training iterations')
plt.ylabel('accuracy')
plt.show()
# Out:
# Iteration 1 Training accuracy: 0.25600001215934753
# Iteration 1 Testing accuracy: 0.2395000010728836
# Iteration 2 Training accuracy: 0.25600001215934753
# Iteration 2 Testing accuracy: 0.2395000010728836
# Iteration 3 Training accuracy: 0.25600001215934753
# Iteration 3 Testing accuracy: 0.2395000010728836
# Iteration 4 Training accuracy: 0.25600001215934753
# Iteration 4 Testing accuracy: 0.2395000010728836
# Iteration 5 Training accuracy: 0.24287499487400055
# Iteration 5 Testing accuracy: 0.25949999690055847
# Iteration 6 Training accuracy: 0.24287499487400055
# Iteration 6 Testing accuracy: 0.25949999690055847
# Iteration 7 Training accuracy: 0.24287499487400055
# Iteration 7 Testing accuracy: 0.25949999690055847
# Iteration 8 Training accuracy: 0.24287499487400055
# Iteration 8 Testing accuracy: 0.25949999690055847
# Iteration 9 Training accuracy: 0.24287499487400055
# Iteration 9 Testing accuracy: 0.25949999690055847
# Iteration 10 Training accuracy: 0.24287499487400055
# Iteration 10 Testing accuracy: 0.25949999690055847

# %% [markdown]
# **1. c) [1 mark]** Try making the network deeper by adding a second layer of neurons.  Use 500 neurons in each of the two middle layers.  Generate the same plot as in 1a.  Does making the network larger in this way improve performance significantly?

# %%
# add a second layer of neurons

class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.fc1 = nn.Linear(4, 500)    # the weights from the input to the new learned features (hidden layer)
        self.fc2 = nn.Linear(500, 500)    # the weights from the hidden layer to the output
        self.fc3 = nn.Linear(500, 4)    # the weights from the hidden layer to the output

    def forward(self, x):
        # the processing the network will do
        x = F.relu(self.fc1(x))         # apply the first set of weights, then apply the ReLU neuron model
        x = F.relu(self.fc2(x))         # apply the second set of weights
        x = self.fc3(x)                 # apply the third set of weights
        return x

network = Net()

# create the learning rule
optimizer = torch.optim.SGD(network.parameters(), 
                            lr=0.1,   # learning rate
                            momentum=0.5)

# variables to keep track of the training and testing accuracy
accuracy_train = []
accuracy_test = []

for i in range(10):
    continue_training()

# plot
plt.figure(figsize=(12,4))
plt.plot(accuracy_train, label='training')
plt.plot(accuracy_test, label='testing')
plt.legend()
plt.xlabel('training iterations')
plt.ylabel('accuracy')
plt.show()
# Out:
# Iteration 1 Training accuracy: 0.24287499487400055
# Iteration 1 Testing accuracy: 0.25949999690055847
# Iteration 2 Training accuracy: 0.24287499487400055
# Iteration 2 Testing accuracy: 0.25949999690055847
# Iteration 3 Training accuracy: 0.24287499487400055
# Iteration 3 Testing accuracy: 0.25949999690055847
# Iteration 4 Training accuracy: 0.24287499487400055
# Iteration 4 Testing accuracy: 0.25949999690055847
# Iteration 5 Training accuracy: 0.24287499487400055
# Iteration 5 Testing accuracy: 0.25949999690055847
# Iteration 6 Training accuracy: 0.24287499487400055
# Iteration 6 Testing accuracy: 0.25949999690055847
# Iteration 7 Training accuracy: 0.24287499487400055
# Iteration 7 Testing accuracy: 0.25949999690055847
# Iteration 8 Training accuracy: 0.24287499487400055
# Iteration 8 Testing accuracy: 0.25949999690055847
# Iteration 9 Training accuracy: 0.24287499487400055
# Iteration 9 Testing accuracy: 0.25949999690055847
# Iteration 10 Training accuracy: 0.24287499487400055
# Iteration 10 Testing accuracy: 0.25949999690055847

# %% [markdown]
# **Answer:**
#
# Adding a second layer of neurons with 500 neurons in each of the two middle layers does not improve performance significantly. The accuracy of the model is similar to the accuracy of the model with a single layer of 500 neurons.

# %% [markdown]
# **1. d) [1 mark]** Starting with the original model in question 1a, let's modify the network in a different way.  In particular, in the current version of the model we have no neuron model at the output.  This is due to this part of the code:
#
# ```python
#     def forward(self, x):
#         # the processing the network will do
#         x = F.relu(self.fc1(x))         # apply the first set of weights, then apply the ReLU neuron model
#         x = self.fc2(x)                 # apply the second set of weights
#         return x
# ```
#
# For the first line (the hidden layer), we use a Rectified Linear neuron model (`F.relu`).  But we aren't doing that with the second line, where it creates the output.  Let's try adding a neuron model there by changing `x = self.fc2(x)` to `x = F.relu(self.fc2(x))`.
#
# Train the model again (by calling `continue_training` 10 times) and make the same plot as above.  Does this improve performance significantly?

# %%
# changing `x = self.fc2(x)` to `x = F.relu(self.fc2(x))`.

class Net(nn.Module):
    def __init__(self, x):
        super(Net, self).__init__()
        self.fc1 = nn.Linear(4, x)    # the weights from the input to the new learned features (hidden layer)
        self.fc2 = nn.Linear(x, 4)    # the weights from the hidden layer to the output

    def forward(self, x):
        # the processing the network will do
        x = F.relu(self.fc1(x))         # apply the first set of weights, then apply the ReLU neuron model
        x = F.relu(self.fc2(x))     # apply the second set of weights
        return x

network = Net(100)

# create the learning rule
optimizer = torch.optim.SGD(network.parameters(), 
                            lr=0.1,   # learning rate
                            momentum=0.5)

# variables to keep track of the training and testing accuracy
accuracy_train = []
accuracy_test = []

for i in range(10):
    continue_training()

# plot
plt.figure(figsize=(12,4))
plt.plot(accuracy_train, label='training')
plt.plot(accuracy_test, label='testing')
plt.legend()
plt.xlabel('training iterations')
plt.ylabel('accuracy')
plt.show()
# Out:
# Iteration 1 Training accuracy: 0.25600001215934753
# Iteration 1 Testing accuracy: 0.2395000010728836
# Iteration 2 Training accuracy: 0.2498749941587448
# Iteration 2 Testing accuracy: 0.2395000010728836
# Iteration 3 Training accuracy: 0.2516250014305115
# Iteration 3 Testing accuracy: 0.2395000010728836
# Iteration 4 Training accuracy: 0.2511250078678131
# Iteration 4 Testing accuracy: 0.2395000010728836
# Iteration 5 Training accuracy: 0.25600001215934753
# Iteration 5 Testing accuracy: 0.2395000010728836
# Iteration 6 Training accuracy: 0.24787500500679016
# Iteration 6 Testing accuracy: 0.2540000081062317
# Iteration 7 Training accuracy: 0.24787500500679016
# Iteration 7 Testing accuracy: 0.2540000081062317
# Iteration 8 Training accuracy: 0.24787500500679016
# Iteration 8 Testing accuracy: 0.2540000081062317
# Iteration 9 Training accuracy: 0.24787500500679016
# Iteration 9 Testing accuracy: 0.2540000081062317
# Iteration 10 Training accuracy: 0.24787500500679016
# Iteration 10 Testing accuracy: 0.2540000081062317

# %% [markdown]
#   Does this improve performance significantly?
#
# No, the accuracy remains at a similar range as before.

# %% [markdown]
# **1. e) [1 mark]** Repeat 1.d but use `F.sigmoid` instead of `F.relu` for the output.  Plot the same graph as before.  You should see that this change makes an improvement over the results in the previous questions.  Why is this the case?

# %%
class Net(nn.Module):
    def __init__(self, x):
        super(Net, self).__init__()
        self.fc1 = nn.Linear(4, x)    # the weights from the input to the new learned features (hidden layer)
        self.fc2 = nn.Linear(x, 4)    # the weights from the hidden layer to the output

    def forward(self, x):
        # the processing the network will do
        x = F.relu(self.fc1(x))         # apply the first set of weights, then apply the ReLU neuron model
        x = F.sigmoid(self.fc2(x))     # apply the second set of weights
        return x

network = Net(100)

# create the learning rule
optimizer = torch.optim.SGD(network.parameters(), 
                            lr=0.1,   # learning rate
                            momentum=0.5)

# variables to keep track of the training and testing accuracy
accuracy_train = []
accuracy_test = []

for i in range(10):
    continue_training()

# plot
plt.figure(figsize=(12,4))
plt.plot(accuracy_train, label='training')
plt.plot(accuracy_test, label='testing')
plt.legend()
plt.xlabel('training iterations')
plt.ylabel('accuracy')
plt.show()
# Out:
# Iteration 1 Training accuracy: 0.7568749785423279
# Iteration 1 Testing accuracy: 0.7524999976158142
# Iteration 2 Training accuracy: 0.765874981880188
# Iteration 2 Testing accuracy: 0.7534999847412109
# Iteration 3 Training accuracy: 0.7636250257492065
# Iteration 3 Testing accuracy: 0.7534999847412109
# Iteration 4 Training accuracy: 0.7622500061988831
# Iteration 4 Testing accuracy: 0.753000020980835
# Iteration 5 Training accuracy: 0.7620000243186951
# Iteration 5 Testing accuracy: 0.7494999766349792
# Iteration 6 Training accuracy: 0.7613750100135803
# Iteration 6 Testing accuracy: 0.7480000257492065
# Iteration 7 Training accuracy: 0.7591249942779541
# Iteration 7 Testing accuracy: 0.746999979019165
# Iteration 8 Training accuracy: 0.7581250071525574
# Iteration 8 Testing accuracy: 0.7450000047683716
# Iteration 9 Training accuracy: 0.7578750252723694
# Iteration 9 Testing accuracy: 0.7425000071525574
# Iteration 10 Training accuracy: 0.7577499747276306
# Iteration 10 Testing accuracy: 0.7434999942779541

# %% [markdown]
# **Answer:**
#
# The sigmoid function is a better choice for the output layer because it ensures that the output is between 0 and 1 (essentially probabilities).

# %% [markdown]
# **1. f) [1 mark]** Try replacing the `F.sigmoid` with `F.softmax`.  The softmax function will scale up the largest value while scaling down the smaller values.  Repeat the previous question and plot the same graph.  You should see an even bigger improvement.  Why is this the case?

# %%
class Net(nn.Module):
    def __init__(self, x):
        super(Net, self).__init__()
        self.fc1 = nn.Linear(4, x)    # the weights from the input to the new learned features (hidden layer)
        self.fc2 = nn.Linear(x, 4)    # the weights from the hidden layer to the output

    def forward(self, x):
        # the processing the network will do
        x = F.relu(self.fc1(x))         # apply the first set of weights, then apply the ReLU neuron model
        x = F.softmax(self.fc2(x))     # apply the second set of weights
        return x

network = Net(100)

# create the learning rule
optimizer = torch.optim.SGD(network.parameters(), 
                            lr=0.1,   # learning rate
                            momentum=0.5)

# variables to keep track of the training and testing accuracy
accuracy_train = []
accuracy_test = []

for i in range(10):
    continue_training()

# plot
plt.figure(figsize=(12,4))
plt.plot(accuracy_train, label='training')
plt.plot(accuracy_test, label='testing')
plt.legend()
plt.xlabel('training iterations')
plt.ylabel('accuracy')
plt.show()
# Out:
# /var/folders/j4/lhlw9vy94dj320jbdphcvs100000gq/T/ipykernel_38819/3354844428.py:12: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   x = F.softmax(self.fc2(x))     # apply the second set of weights
# Iteration 1 Training accuracy: 0.6269999742507935
# Iteration 1 Testing accuracy: 0.6424999833106995
# Iteration 2 Training accuracy: 0.8456249833106995
# Iteration 2 Testing accuracy: 0.8510000109672546
# Iteration 3 Training accuracy: 0.9256250262260437
# Iteration 3 Testing accuracy: 0.9304999709129333
# Iteration 4 Training accuracy: 0.953125
# Iteration 4 Testing accuracy: 0.953499972820282
# Iteration 5 Training accuracy: 0.9679999947547913
# Iteration 5 Testing accuracy: 0.9700000286102295
# Iteration 6 Training accuracy: 0.9768750071525574
# Iteration 6 Testing accuracy: 0.9779999852180481
# Iteration 7 Training accuracy: 0.9831249713897705
# Iteration 7 Testing accuracy: 0.9865000247955322
# Iteration 8 Training accuracy: 0.9848750233650208
# Iteration 8 Testing accuracy: 0.9894999861717224
# Iteration 9 Training accuracy: 0.9866250157356262
# Iteration 9 Testing accuracy: 0.9915000200271606
# Iteration 10 Training accuracy: 0.9890000224113464
# Iteration 10 Testing accuracy: 0.9904999732971191

# %% [markdown]
# ** Answer **: The softmax function is used to convert the output of the network into a probability distribution.  This is useful when the output of the network is a multi class classification problem.  The softmax function will scale up the largest value while scaling down the smaller values. Since there are more than 2 possible classifications, the softmax function is more appropriate than the sigmoid function.

# %% [markdown]
# **1. g) [1 mark]** Even though the model you built in 1f) does a good job of solving the task of producing the correct output, it seems to do this only if we include a `softmax` operation.  How might this be considered "cheating" (and thus this should not considered to be a good model of action selection in the brain)?

# %% [markdown]
# # 2. Action Selection with Winner-Take-All
#
# Given the results of the previous section, we need a different approach to do action selection.  Since a feed-forward approach led to difficulties, here we will explore a recurrent network: the standard "winner-take-all" circuit.  In this system, each neuron excites itself but inhibits the other neurons.
#
# Crucially, since this approach is recurrent, we can't just feed in an input and get an output.  Instead, we will feed in an input over time and see what the output is over time.  Rather than implement this in `pytorch`, we will just use normal numpy commands.
#
# The main configurable part of the model is how nuch the neurons excite themselves and how much they inhibit other neurons.  We can build this as a weight matrix that has the excitation on the diagonal and the inhibition everywhere else:

# %%
w = np.zeros((N,N))
w[:] = -0.9   # set the inhibition amount everywhere
for i in range(N):
    w[i,i] = 1   # set the excitatory connection
    
print(w)
# Out:
# [[ 1.  -0.9 -0.9 -0.9]
#  [-0.9  1.  -0.9 -0.9]
#  [-0.9 -0.9  1.  -0.9]
#  [-0.9 -0.9 -0.9  1. ]]

# %% [markdown]
# To run the model, we pick a particular input that set that we will provide.  We then feed that value into the model, and add the value that the neurons send back to themselves.  We also include a `clip` operation that stops the neuron value from going below 0 or above 1.  We repeat this process multiple times, and we record the activity of the neurons so we can plot it afterwards.

# %% [markdown]
# **2. a) [1 mark]**  Run the model with an input of `[0.7, 0.8, 0.4, 0.3]`.  Plot the `record` of the activity.  Print the final `activity` value.  Does the network successfully output the desired correct results of `[0, 1, 0, 0]`?

# %%
input_values = np.array([0.7, 0.8, 0.4, 0.3])
record = []                   # for recording the activity values
activity = np.zeros(N)        # neurons are not active initially
for i in range(10):
    # the new neuron value is the old value times the weight matrix (for the neurons 
    #  inhibiting and exciting each other), plus the input benig added.
    # we also clip the neurons so their activity doesn't go below 0 or above 1
    activity = np.clip(input_values + w @ activity, 0, 1)
    record.append(activity)

# plot the record
plt.figure(figsize=(12,4))
plt.plot(record)
plt.xlabel('time')
plt.ylabel('activity')
plt.legend(['neuron 1', 'neuron 2', 'neuron 3', 'neuron 4'])
plt.show()

# %% [markdown]
# Yes, the model outputs the correct prediction (neuron 2)

# %% [markdown]
# **2. b) [1 mark]**  Test the model using all the data in the `X` dataset you created in question 1.  (This should be all 10000 sets of 4 randomly generated numbers).  Note that since we didn't use any data to train the model, we are using all of it to test the model.
#
# To test the model, loop through all the items (`for input_values in X:`) and run the model as in question 2a.  To determine if the output is correct, you can do
#
# ```python
#     target = np.zeros(N)
#     target[np.argmax(input_values)] = 1
#     if np.all(target == activity):
#         correct += 1
# ```
#
# What proportion of the time does the model produce the correct output?

# %%
# test the model
correct = 0
for input_values in X:
    record = []                   # for recording the activity values
    activity = np.zeros(N)        # neurons are not active initially
    for i in range(10):
        # the new neuron value is the old value times the weight matrix (for the neurons 
        #  inhibiting and exciting each other), plus the input benig added.
        # we also clip the neurons so their activity doesn't go below 0 or above 1
        activity = np.clip(input_values + w @ activity, 0, 1)
        record.append(activity)
        
    target = np.zeros(N)
    target[np.argmax(input_values)] = 1
    if np.all(target == activity):
        correct += 1

# What proportion of the time does the model produce the correct output?
print('Proportion of correct outputs:', correct/len(X))
# Out:
# Proportion of correct outputs: 0.8014

# %% [markdown]
# **2. c) [1 mark]**  Try running the model for a longer time, rather than the 10 steps in the code provided.  Try 10, 20, 50, 100, 200, and 500.  Make a plot showing the proportion of time the model produces the ideal output for each of those numbers of timesteps.

# %%
correct_proportions = []

for timesteps in [10, 20, 50, 100, 200, 500]:
    correct = 0
    for input_values in X:
        record = []                   # for recording the activity values
        activity = np.zeros(N)        # neurons are not active initially
        for i in range(timesteps):
            # the new neuron value is the old value times the weight matrix (for the neurons 
            #  inhibiting and exciting each other), plus the input benig added.
            # we also clip the neurons so their activity doesn't go below 0 or above 1
            activity = np.clip(input_values + w @ activity, 0, 1)
            record.append(activity)

        target = np.zeros(N)
        target[np.argmax(input_values)] = 1
        if np.all(target == activity):
            correct += 1

    # What proportion of the time does the model produce the correct output?
    correct_proportions.append(correct/len(X))


# plot
plt.figure(figsize=(12,4))
plt.plot([10, 20, 50, 100, 200, 500], correct_proportions)
plt.xlabel('timesteps')
plt.ylabel('proportion correct')
plt.show()

# %% [markdown]
# **2. d) [2 marks]**  Try improving the model by adjusting the amount of inhibition (-0.9) and the amount of excitation (1).  Can you improve the proportion of time the model produces the correction output?  To simplify your experimentation, keep the number of timesteps as 20.

# %%
correct_proportions = []

for inhibition in [-0.9, -0.7, -0.5]:
    for excitation in [0.6, 0.8, 1, 1.2]:
        w = np.zeros((N,N))
        w[:] = inhibition   # set the inhibition amount everywhere
        for i in range(N):
            w[i,i] = excitation   # set the excitatory connection

        correct = 0
        for input_values in X:
            record = []                   # for recording the activity values
            activity = np.zeros(N)        # neurons are not active initially
            for i in range(20):
                # the new neuron value is the old value times the weight matrix (for the neurons 
                #  inhibiting and exciting each other), plus the input benig added.
                # we also clip the neurons so their activity doesn't go below 0 or above 1
                activity = np.clip(input_values + w @ activity, 0, 1)
                record.append(activity)

            target = np.zeros(N)
            target[np.argmax(input_values)] = 1
            if np.all(target == activity):
                correct += 1

        # What proportion of the time does the model produce the correct output?
        correct_proportions.append(correct/len(X))
        print('inhibition:', inhibition, 'excitation:', excitation, 'correct proportion:', correct/len(X))

# plot
plt.figure(figsize=(12,4))
plt.plot(correct_proportions)
plt.xlabel('experiment number')
plt.ylabel('proportion correct')
plt.show()
# Out:
# inhibition: -0.9 excitation: 0.6 correct proportion: 0.658
# inhibition: -0.9 excitation: 0.8 correct proportion: 0.7981
# inhibition: -0.9 excitation: 1 correct proportion: 0.8497
# inhibition: -0.9 excitation: 1.2 correct proportion: 0.8006
# inhibition: -0.7 excitation: 0.6 correct proportion: 0.5993
# inhibition: -0.7 excitation: 0.8 correct proportion: 0.6352
# inhibition: -0.7 excitation: 1 correct proportion: 0.5999
# inhibition: -0.7 excitation: 1.2 correct proportion: 0.4873
# inhibition: -0.5 excitation: 0.6 correct proportion: 0.2755
# inhibition: -0.5 excitation: 0.8 correct proportion: 0.3009
# inhibition: -0.5 excitation: 1 correct proportion: 0.2767
# inhibition: -0.5 excitation: 1.2 correct proportion: 0.2052

# %% [markdown]
# # 3. Action Selection with Winner-Take-All and a Synapse
#
# We are now going to add a biological detail to the Winner-Take-All system.  In biology, when there is a connection between neurons, there is a synapse, and the activity of that synapse decays slowly over time.  This means that when a spike occurs, the input into the next neuron will suddenly increase, and then slowly decrease.
#
# Here we will make a simple approximation of this process.  We will be implementing this as a *low-pass filter*.  The only parameter is the one that controls how quickly the synaptic activity will decay, and we will call this `tau`.  To implement a low-pass filter as part of our neuron model, we can compute the synaptic activity as follows, where `dt` is how long one timestep is in our model:
#
# ```python
# alpha = 1-np.exp(-dt/tau)
#
# activity_syn = activity_syn + alpha * (activity - activity_syn)
# ```
#
# Here is what that would look like for a single input that gave a single spike on the 5th timestep, where each timestep is 0.001 seconds and the synaptic time constant is 0.01 seconds (10 milliseconds):

# %%
# activity - np.zeros(1)
activity_syn = np.zeros(1)

dt = 0.001    # length of a timestep
tau = 0.010   # time constant for the synapse
alpha = 1-np.exp(-dt/tau)
record = []
for i in range(40):
    activity = 0
    if i == 5:
        activity = 1
    activity_syn = activity_syn + alpha * (activity - activity_syn)   
    record.append(activity_syn)

import matplotlib.pyplot as plt
plt.plot(record)
plt.xlabel('timestep')
plt.ylabel('synapse activity')
plt.show()

# %% [markdown]
# While our winner-take-all model is not spiking, we can still add this synapse model to the system.  This would be done as follows:

# %%
record = []             
activity = np.zeros(N)        # the raw output from the neuron
activity_syn = np.zeros(N)    # the output from the synapse
for i in range(20):
    activity = np.clip(input_values + w @ activity_syn, 0, 1)  # note we use activity_syn here, not activity
    activity_syn += alpha * (activity - activity_syn)          # implement the synapse 

    record.append(activity_syn)

# %% [markdown]
# **3. a) [1 mark]** Test the winner-take-all model with a synapse time constant of 10 milliseconds, inhibition of -0.9, and excitation of 1 against all the data in `X`, running it for 20 timesteps (with each timestep being 1 millisecond).  What proportion of time does it get the correct answer?  Repeat this for differet synapse time constants (try 0.001, 0.002, 0.005, 0.01, and 0.02 seconds) and generate a plot showing the accuracy as you change the time constant.

# %%
correct_proportions = []
dt = 0.001

# iterate over different values of tau
for tau in [0.001, 0.002, 0.005, 0.01, 0.02]:
    alpha = 1-np.exp(-dt/tau)
    record = []             
    activity = np.zeros(N)        # the raw output from the neuron
    activity_syn = np.zeros(N)    # the output from the synapse
    correct = 0
    for input_values in X:
        for i in range(20):
            activity = np.clip(input_values + w @ activity_syn, 0, 1)  # note we use activity_syn here, not activity
            activity_syn += alpha * (activity - activity_syn)          # implement the synapse 

            record.append(activity_syn)    

        target = np.zeros(N)
        target[np.argmax(input_values)] = 1
        if np.all(target == activity):
            correct += 1

    # What proportion of the time does the model produce the correct output?
    correct_proportions.append(correct/len(X))
    print('tau:', tau, 'correct proportion:', correct/len(X))

# plot
plt.figure(figsize=(12,4))
plt.plot([0.001, 0.002, 0.005, 0.01, 0.02], correct_proportions)
plt.xlabel('tau')
plt.ylabel('proportion correct')
plt.show()
# Out:
# tau: 0.001 correct proportion: 0.2848
# tau: 0.002 correct proportion: 0.2502
# tau: 0.005 correct proportion: 0.1343
# tau: 0.01 correct proportion: 0.0481
# tau: 0.02 correct proportion: 0.0102

# %% [markdown]
# Smaller time constants resulted in the best accuracy. Accuracy is still low, perhaps due to small equivalency error.

# %% [markdown]
# **3. b) [2 marks]** Try improving the model by adjusting the synaptic time constant, the amount of inhibition and the amount of excitation.  Can you improve the proportion of time the model produces the correct output?  To simplify your experimentation, keep the number of timesteps as 20.  As a hint, you should be able to get the model close to 99% accuracy!  This is an example of adding a biological detail to a model and having it improve its performance.

# %%
correct_proportions = []
dt = 0.001

for inhibition in [-0.9, -0.7, -0.5]:
    for excitation in [0.6, 0.8, 1, 1.2]:
        for tau in [0.001, 0.002, 0.005, 0.01, 0.02]:
            alpha = 1-np.exp(-dt/tau)
            w = np.zeros((N,N))
            w[:] = inhibition   # set the inhibition amount everywhere
            for i in range(N):
                w[i,i] = excitation   # set the excitatory connection

            record = []             
            activity = np.zeros(N)        # the raw output from the neuron
            activity_syn = np.zeros(N)    # the output from the synapse
            correct = 0
            for input_values in X:
                for i in range(20):
                    activity = np.clip(input_values + w @ activity_syn, 0, 1)  # note we use activity_syn here, not activity
                    activity_syn += alpha * (activity - activity_syn)          # implement the synapse 

                    record.append(activity_syn)    

                target = np.zeros(N)
                target[np.argmax(input_values)] = 1
                if np.all(target == activity):
                    correct += 1

            # What proportion of the time does the model produce the correct output?
            correct_proportions.append(correct/len(X))
            print('inhibition:', inhibition, 'excitation:', excitation, 'tau:', tau, 'correct proportion:', correct/len(X))


# plot
plt.figure(figsize=(12,4))
plt.plot(correct_proportions)
plt.xlabel('experiment number')
plt.ylabel('proportion correct')
plt.show()
# Out:
# inhibition: -0.9 excitation: 0.6 tau: 0.001 correct proportion: 0.5544
# inhibition: -0.9 excitation: 0.6 tau: 0.002 correct proportion: 0.5065
# inhibition: -0.9 excitation: 0.6 tau: 0.005 correct proportion: 0.3851
# inhibition: -0.9 excitation: 0.6 tau: 0.01 correct proportion: 0.2727
# inhibition: -0.9 excitation: 0.6 tau: 0.02 correct proportion: 0.1927
# inhibition: -0.9 excitation: 0.8 tau: 0.001 correct proportion: 0.4255
# inhibition: -0.9 excitation: 0.8 tau: 0.002 correct proportion: 0.3926
# inhibition: -0.9 excitation: 0.8 tau: 0.005 correct proportion: 0.3142
# inhibition: -0.9 excitation: 0.8 tau: 0.01 correct proportion: 0.2484
# inhibition: -0.9 excitation: 0.8 tau: 0.02 correct proportion: 0.2287
# inhibition: -0.9 excitation: 1 tau: 0.001 correct proportion: 0.339
# inhibition: -0.9 excitation: 1 tau: 0.002 correct proportion: 0.2937
# inhibition: -0.9 excitation: 1 tau: 0.005 correct proportion: 0.2534
# inhibition: -0.9 excitation: 1 tau: 0.01 correct proportion: 0.2361
# inhibition: -0.9 excitation: 1 tau: 0.02 correct proportion: 0.2412
# inhibition: -0.9 excitation: 1.2 tau: 0.001 correct proportion: 0.3634
# inhibition: -0.9 excitation: 1.2 tau: 0.002 correct proportion: 0.3044
# inhibition: -0.9 excitation: 1.2 tau: 0.005 correct proportion: 0.2478
# inhibition: -0.9 excitation: 1.2 tau: 0.01 correct proportion: 0.2382
# inhibition: -0.9 excitation: 1.2 tau: 0.02 correct proportion: 0.2409
# inhibition: -0.7 excitation: 0.6 tau: 0.001 correct proportion: 0.4918
# inhibition: -0.7 excitation: 0.6 tau: 0.002 correct proportion: 0.4396
# inhibition: -0.7 excitation: 0.6 tau: 0.005 correct proportion: 0.3064
# inhibition: -0.7 excitation: 0.6 tau: 0.01 correct proportion: 0.1983
# inhibition: -0.7 excitation: 0.6 tau: 0.02 correct proportion: 0.1207
# inhibition: -0.7 excitation: 0.8 tau: 0.001 correct proportion: 0.4325
# inhibition: -0.7 excitation: 0.8 tau: 0.002 correct proportion: 0.3823
# inhibition: -0.7 excitation: 0.8 tau: 0.005 correct proportion: 0.283
# inhibition: -0.7 excitation: 0.8 tau: 0.01 correct proportion: 0.2011
# inhibition: -0.7 excitation: 0.8 tau: 0.02 correct proportion: 0.1491
# inhibition: -0.7 excitation: 1 tau: 0.001 correct proportion: 0.3747
# inhibition: -0.7 excitation: 1 tau: 0.002 correct proportion: 0.3239
# inhibition: -0.7 excitation: 1 tau: 0.005 correct proportion: 0.2354
# inhibition: -0.7 excitation: 1 tau: 0.01 correct proportion: 0.1775
# inhibition: -0.7 excitation: 1 tau: 0.02 correct proportion: 0.1542
# inhibition: -0.7 excitation: 1.2 tau: 0.001 correct proportion: 0.3139
# inhibition: -0.7 excitation: 1.2 tau: 0.002 correct proportion: 0.271
# inhibition: -0.7 excitation: 1.2 tau: 0.005 correct proportion: 0.1885
# inhibition: -0.7 excitation: 1.2 tau: 0.01 correct proportion: 0.1541
# inhibition: -0.7 excitation: 1.2 tau: 0.02 correct proportion: 0.1428
# inhibition: -0.5 excitation: 0.6 tau: 0.001 correct proportion: 0.2502
# inhibition: -0.5 excitation: 0.6 tau: 0.002 correct proportion: 0.2234
# inhibition: -0.5 excitation: 0.6 tau: 0.005 correct proportion: 0.1508
# inhibition: -0.5 excitation: 0.6 tau: 0.01 correct proportion: 0.0902
# inhibition: -0.5 excitation: 0.6 tau: 0.02 correct proportion: 0.0448
# inhibition: -0.5 excitation: 0.8 tau: 0.001 correct proportion: 0.2414
# inhibition: -0.5 excitation: 0.8 tau: 0.002 correct proportion: 0.2111
# inhibition: -0.5 excitation: 0.8 tau: 0.005 correct proportion: 0.1442
# inhibition: -0.5 excitation: 0.8 tau: 0.01 correct proportion: 0.0941
# inhibition: -0.5 excitation: 0.8 tau: 0.02 correct proportion: 0.0579
# inhibition: -0.5 excitation: 1 tau: 0.001 correct proportion: 0.1929
# inhibition: -0.5 excitation: 1 tau: 0.002 correct proportion: 0.1647
# inhibition: -0.5 excitation: 1 tau: 0.005 correct proportion: 0.1119
# inhibition: -0.5 excitation: 1 tau: 0.01 correct proportion: 0.0739
# inhibition: -0.5 excitation: 1 tau: 0.02 correct proportion: 0.0478
# inhibition: -0.5 excitation: 1.2 tau: 0.001 correct proportion: 0.1202
# inhibition: -0.5 excitation: 1.2 tau: 0.002 correct proportion: 0.1031
# inhibition: -0.5 excitation: 1.2 tau: 0.005 correct proportion: 0.0675
# inhibition: -0.5 excitation: 1.2 tau: 0.01 correct proportion: 0.0344
# inhibition: -0.5 excitation: 1.2 tau: 0.02 correct proportion: 0.0156

# %%
# additional attempt

import numpy as np

correct_proportions = []
dt = 0.001

for inhibition in np.linspace(-0.85, -0.95, 20):
    for excitation in np.linspace(0., 2, 10):
        for tau in [0.001]:
            alpha = 1-np.exp(-dt/tau)
            w = np.zeros((N,N))
            w[:] = inhibition   # set the inhibition amount everywhere
            for i in range(N):
                w[i,i] = excitation   # set the excitatory connection

            record = []             
            activity = np.zeros(N)        # the raw output from the neuron
            activity_syn = np.zeros(N)    # the output from the synapse
            correct = 0
            for input_values in X:
                for i in range(20):
                    activity = np.clip(input_values + w @ activity_syn, 0, 1)  # note we use activity_syn here, not activity
                    activity_syn += alpha * (activity - activity_syn)          # implement the synapse 

                    record.append(activity_syn)    

                target = np.zeros(N)
                target[np.argmax(input_values)] = 1
                if np.all(target == activity):
                    correct += 1

            # What proportion of the time does the model produce the correct output?
            correct_proportions.append(correct/len(X))
            print('inhibition:', inhibition, 'excitation:', excitation, 'tau:', tau, 'correct proportion:', correct/len(X))


# plot
plt.figure(figsize=(12,4))
plt.plot(correct_proportions)
plt.xlabel('experiment number')
plt.ylabel('proportion correct')
plt.show()
# Out:
# inhibition: -2.0 excitation: 0.0 tau: 0.001 correct proportion: 0.0
